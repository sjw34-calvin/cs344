# %% [markdown]
# # Home Work 4

# %% [markdown]
# # Part 1

# %% [markdown]
# The research on AI first began way back in 1956 at Dartmouth College. In the decades since, AI has come under a lot of
# controversy and dead periods. Artificial neural networks came from the early-machine learning crowd and like many other
# algorithms they went. The problem in the early days was that even the most basic neural networks very computationally
# intensive, so it just wasn't a practical approach. It wasn't until a small research group at the University of Toronto was
# able to parallelize the process for supercomputers and the deployment of GPU's what gave ANN's a boost.
#
# Andrew Ng's breakthrough was with these networks was to take these neural networks and essentially make them huge, increase
# the layers and the neurons, and then run massive amounts of data through the system to train it.
#
# I think that in this current day and age the problems that we are trying to solve using AI work with deep neural networks.
# Who knows where we will be with technology in the next 10-20 years with the current fast pace of growth that technology is
# experiencing. Right now large neural networks can take anywhere from 10 seconds to a couple weeks to train depending on the
# size and context of the problem. So right now they seem to work fine but ultimately they don't have real intelligence and they
# are hard to understand and can be unpredictable. They are in many cases more accurate than humans at doing many real-world
# problems such as:
# 1) Tesla's auto-pilot feature
# 2) Google Go player which beat the world champion a few years ago
# 3) Google Translate
# 4) Image recognition  etc.
#
# In conclusion, I don't think that deep networks are or ever will be a complete bust. I can however, see them evolving alot over time as we begin to understand more and more of the algorithms and hidden layers that we currently have limited understanding of.

# %% [markdown]
# # Part 2
#
# I did attach the hand written solutions here and when I run it in Jupyter notebook they run and display fine. But when I go and submit it to github I can't see them. For that reason I am also throwing the two images in the homework folder.

# %% [markdown]
# ![homework4-1.jpeg](attachment:homework4-1.jpeg)
# ![homework4-2.jpeg](attachment:homework4-2.jpeg)

# %% [markdown]
# # Part 3

# %%
# Sameer Mall
# Homework 4
# 04/11/19

from keras import layers
from keras import models
from keras.datasets import fashion_mnist
from keras.utils import to_categorical
model = models.Sequential()

# Configure a convnet with 3 layers of convolutions and max pooling.
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))



# Add layers to flatten the 2D image and then do a 10-way classification.
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))


model.summary()

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype('float32') / 255

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit(train_images, train_labels, epochs=30, batch_size=64)
model.evaluate(test_images, test_labels)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /home/sjw34/Desktop/cs344/code/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# ...

# %% [markdown]
# The Network that worked best for me had 2 layers with 2 max pooling operations. Initially, I experimented with 3 layers which gave me an accuracy of 88.53% but when I removed a layer I got 90.55% accuracy.
